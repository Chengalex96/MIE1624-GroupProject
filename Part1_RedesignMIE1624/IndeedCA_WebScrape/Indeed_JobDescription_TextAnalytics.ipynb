# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ba = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/0-Business%20Analysts/CA-JobMarket-BusinessAnalyst-softskills.csv', 
                 index_col=0)
ba['job_category'] = 'Business Analyst'

da = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/1-Data%20Analysts/CA-JobMarket-DataAnalyst-softskills.csv',
                 index_col=0)
da['job_category'] = 'Data Analyst'

de = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/2-Data%20Engineers/CA-JobMarket-DataEngineer-softskills.csv',
                 index_col=0)
de['job_category'] = 'Data Engineer'

dm = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/3-Data%20Manager/CA-JobMarket-DataManager-softskills.csv',
                 index_col=0)
dm['job_category'] = 'Data Manager'

ds = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/4-Data%20Scientists/CA-JobMarket-DataScientist-softskills.csv',
                 index_col=0)
ds['job_category'] = 'Data Scientist'

mle = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/5-Machine%20Learning%20Engineers/CA-JobMarket-MLEngineer-softskills.csv',
                 index_col=0)
mle['job_category'] = 'Machine Learning Engineer'

df = ba.append(da).append(de).append(dm).append(ds).append(mle).reset_index(drop=True)
df.head()
# Out:
#    Job Title Index  ...      job_category
# 0                0  ...  Business Analyst
# 1                0  ...  Business Analyst
# 2                0  ...  Business Analyst
# 3                0  ...  Business Analyst
# 4                0  ...  Business Analyst
#
# [5 rows x 19 columns]

# %%
soft_skills = ['team', 'communication', 'research', 'presentation', 'learning', 'decision making', 'creativity', 'critical thinking', 'analytical thinking', 'curiosity', 'domain knowledge','report writing', 'business acumen']
df.groupby('job_category').sum()[soft_skills] / df.groupby('job_category').count()[soft_skills]
# Out:
#                                team  ...  business acumen
# job_category                         ...
# Business Analyst           0.896373  ...         0.015544
# Data Analyst               0.852174  ...         0.069565
# Data Engineer              0.873913  ...         0.004348
# Data Manager               0.946970  ...         0.053030
# Data Scientist             0.904255  ...         0.010638
# Machine Learning Engineer  0.964444  ...         0.000000
#
# [6 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))
data = df.groupby('job_category').sum()[soft_skills] / df.groupby('job_category').count()[soft_skills]
data = data.unstack().reset_index().rename({'level_0': 'skill', 0:'pct'}, axis=1)
sns.barplot(x='skill', y='pct', hue='job_category', data=data)
plt.xticks(rotation=70)
plt.ylabel('% share in Job Descriptions')
plt.title('All Job Families')
plt.show()

# %%
ba = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/0-Business%20Analysts/CA-JobMarket-BusinessAnalyst-tools.csv', 
                 index_col=0)
ba['job_category'] = 'Business Analyst'

da = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/1-Data%20Analysts/CA-JobMarket-DataAnalyst-tools.csv',
                 index_col=0)
da['job_category'] = 'Data Analyst'

de = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/2-Data%20Engineers/CA-JobMarket-DataEngineer-tools.csv',
                 index_col=0)
de['job_category'] = 'Data Engineer'

dm = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/3-Data%20Manager/CA-JobMarket-DataManager-tools.csv',
                 index_col=0)
dm['job_category'] = 'Data Manager'

ds = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/4-Data%20Scientists/CA-JobMarket-DataScientist-tools.csv',
                 index_col=0)
ds['job_category'] = 'Data Scientist'

mle = pd.read_csv('https://raw.githubusercontent.com/Navyhoang/MIE1624-GroupProject/main/WebScrape/Indeed-data/5-Machine%20Learning%20Engineers/CA-JobMarket-MLEngineer-tools.csv',
                 index_col=0)
mle['job_category'] = 'Machine Learning Engineer'

df = ba.append(da).append(de).append(dm).append(ds).append(mle).reset_index(drop=True)
df.head()
# Out:
#    Job Title Index                     Job Title  ... Qlik      job_category
# 0                0              Business Analyst  ...    0  Business Analyst
# 1                0              Business Analyst  ...    0  Business Analyst
# 2                0           IT Business Analyst  ...    0  Business Analyst
# 3                0      Analyst-Business Systems  ...    0  Business Analyst
# 4                0  Business Integration Analyst  ...    0  Business Analyst
#
# [5 rows x 34 columns]

# %%
hard_skills = ['Excel', 'Python',  'SQL', 'NoSQL', 'pyspark', 'java', 'Javascript', 'html', 'Julia', 'Swift', 'Bash', 'Matlab', 'GCP', 'AWS', 'Azure', 'Big data', 'Hadoop', 'MySQL', 'PostgreSQL', 'Oracle', 'MongoDB', 'Snowflake', 'IBM', 'Redshift', 'Power BI', 'Tableau', 'SAP', 'Qlik']
df.groupby('job_category').sum()[hard_skills] / df.groupby('job_category').count()[hard_skills]
# Out:
#                               Excel    Python  ...       SAP      Qlik
# job_category                                   ...
# Business Analyst           0.616580  0.046632  ...  0.088083  0.005181
# Data Analyst               0.678261  0.321739  ...  0.052174  0.008696
# Data Engineer              0.917391  0.591304  ...  0.186957  0.000000
# Data Manager               0.666667  0.121212  ...  0.121212  0.030303
# Data Scientist             0.510638  0.851064  ...  0.042553  0.010638
# Machine Learning Engineer  0.426667  0.804444  ...  0.048889  0.004444
#
# [6 rows x 28 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))
data = df.groupby('job_category').sum()[hard_skills] / df.groupby('job_category').count()[hard_skills]
data = data.unstack().reset_index().rename({'level_0': 'skill', 0:'pct'}, axis=1)
sns.barplot(x='skill', y='pct', hue='job_category', data=data)
plt.xticks(rotation=70)
plt.ylabel('% share in Job Descriptions')
plt.title('All Job Families')
plt.show()

# %%
df = df.rename({'Job Description': 'job_description'}, axis=1)[['job_category', 'job_description']]
df.head()
# Out:
#        job_category                                    job_description
# 0  Business Analyst  We believe that owning your work and claiming ...
# 1  Business Analyst  About UsStay Inc. is a fast-growing start up l...
# 2  Business Analyst  The RCMP consists of 30,000+ employees working...
# 3  Business Analyst  The Analyst-Business Systems is responsible fo...
# 4  Business Analyst  Required skills: Technical background - prior ...

# %%
stop_words  = pd.read_csv('https://raw.githubusercontent.com/lisanka93/text_analysis_python_101/master/SmartStoplist.txt',
                          parse_dates=[0]).to_numpy()

# %%
extension = ['sexual', 'orientation', 'color', 'race', 'veteran', 'nationality', 'status', 'diversity', 'inclusion', 'opportunity', 'equal', 'employer', 'affirmative', 'action', 'origin', 'gender', 'identity', 'medical', 'dental', 'vision', 'benefit']
for word in extension:
  stop_words= np.append(stop_words, word)

# %%
import re
from nltk.stem import WordNetLemmatizer, PorterStemmer, SnowballStemmer

def preprocess(raw_text):
    
    #regular expression keeping only letters 
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split into words -> convert string into list ( 'hello world' -> ['hello', 'world'])
    words = letters_only_text.lower().split()

    cleaned_words = []
    lemmatizer = PorterStemmer() #plug in here any other stemmer or lemmatiser you want to try out
    
    # remove stopwords
    for word in words:
        if word not in stop_words:
            cleaned_words.append(word)
    
    # stemm or lemmatise words
    stemmed_words = []
    for word in cleaned_words:
        word = lemmatizer.stem(word)   #dont forget to change stem to lemmatize if you are using a lemmatizer
        stemmed_words.append(word)
    
    # converting list back to string
    return " ".join(stemmed_words)

# %%
df['prep'] = df['job_description'].apply(preprocess)
df.head()
# Out:
#        job_category  ...                                               prep
# 0  Business Analyst  ...  own work claim respons key satisfact work thin...
# 1  Business Analyst  ...  usstay fast grow start launch onlin marketplac...
# 2  Business Analyst  ...  rcmp consist employe work commun safe canada t...
# 3  Business Analyst  ...  analyst busi system respons facilit develop im...
# 4  Business Analyst  ...  requir skill technic background prior system a...
#
# [5 rows x 3 columns]

# %%
from collections import Counter
Counter(" ".join(df["prep"]).split()).most_common(10)
# Out:
# [('data', 7513),
#  ('work', 5119),
#  ('busi', 4589),
#  ('team', 4151),
#  ('experi', 4079),
#  ('manag', 3448),
#  ('develop', 3184),
#  ('requir', 2709),
#  ('learn', 2563),
#  ('project', 2100)]

# %%
#nice library to produce wordclouds
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in df["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1200, height = 700, 
                background_color ='white', 
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (12, 7), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
categories = ['Business Analyst', 'Data Analyst', 'Data Engineer', 'Data Manager', 'Data Scientist', 'Machine Learning Engineer']
for cat in categories:
  all_words = '' 

  #looping through all incidents and joining them to one text, to extract most common words
  for arg in df[df['job_category']==cat]["prep"]: 

      tokens = arg.split()  
        
      all_words += " ".join(tokens)+" "

  wordcloud = WordCloud(width = 1200, height = 700, 
                  background_color ='white', 
                  min_font_size = 10).generate(all_words) 
    
  # plot the WordCloud image        
  print('\nFor Job Category:', cat)                
  plt.figure(figsize = (12, 7), facecolor = None) 
  plt.imshow(wordcloud) 
  plt.axis("off") 
  plt.tight_layout(pad = 0) 
    
  plt.show()
# Out:
# For Job Category: Business Analyst
# For Job Category: Data Analyst
# For Job Category: Data Engineer
# For Job Category: Data Manager
# For Job Category: Data Scientist
# For Job Category: Machine Learning Engineer

# %%
from nltk.util import ngrams
from collections import OrderedDict

n_gram = 2
n_gram_dic = dict(Counter(ngrams(all_words.split(), n_gram)))
n_gram_dic = OrderedDict(sorted(n_gram_dic.items(), key=lambda kv: kv[1], reverse=True))

for i in n_gram_dic:
    if n_gram_dic[i] >= 20:
        print(i, n_gram_dic[i])
# Out:
# ('machin', 'learn') 1337
# ('data', 'scienc') 582
# ('year', 'experi') 445
# ('problem', 'solv') 386
# ('comput', 'scienc') 348
# ('data', 'analysi') 332
# ('data', 'scientist') 322
# ('commun', 'skill') 311
# ('project', 'manag') 304
# ('team', 'member') 299
# ('data', 'analyt') 294
# ('full', 'time') 289
# ('data', 'manag') 281
# ('experi', 'work') 271
# ('busi', 'analyst') 268
# ('busi', 'system') 254
# ('fast', 'pace') 246
# ('work', 'close') 230
# ('busi', 'process') 228
# ('softwar', 'develop') 227
# ('deep', 'learn') 222
# ('busi', 'requir') 210
# ('work', 'environ') 210
# ('cross', 'function') 209
# ('skill', 'abil') 209
# ('data', 'driven') 200
# ('type', 'full') 188
# ('relat', 'field') 188
# ('decis', 'make') 186
# ('qualifi', 'applic') 170
# ('bachelor', 'degre') 169
# ('busi', 'intellig') 167
# ('experi', 'data') 166
# ('data', 'visual') 161
# ('recruit', 'process') 160
# ('manag', 'data') 160
# ('subject', 'matter') 159
# ('manag', 'team') 158
# ('end', 'end') 156
# ...

# %%
from nltk.util import ngrams
from collections import OrderedDict

n_gram = 3
n_gram_dic = dict(Counter(ngrams(all_words.split(), n_gram)))
n_gram_dic = OrderedDict(sorted(n_gram_dic.items(), key=lambda kv: kv[1], reverse=True))

for i in n_gram_dic:
    if n_gram_dic[i] >= 10:
        print(i, n_gram_dic[i])
# Out:
# Streaming output truncated to the last 5000 lines.
# ('abreast', 'industri', 'technic') 15
# ('industri', 'technic', 'busi') 15
# ('technic', 'busi', 'trend') 15
# ('busi', 'trend', 'particip') 15
# ('trend', 'particip', 'profession') 15
# ('particip', 'profession', 'associ') 15
# ('profession', 'associ', 'practic') 15
# ('associ', 'practic', 'commun') 15
# ('practic', 'commun', 'individu') 15
# ('commun', 'individu', 'learn') 15
# ('individu', 'learn', 'focu') 15
# ('learn', 'focu', 'primarili') 15
# ('focu', 'primarili', 'busi') 15
# ('primarili', 'busi', 'group') 15
# ('busi', 'group', 'bmo') 15
# ('group', 'bmo', 'broader') 15
# ('bmo', 'broader', 'enterpris') 15
# ('broader', 'enterpris', 'wide') 15
# ('enterpris', 'wide', 'focu') 15
# ('exercis', 'judgment', 'identifi') 15
# ('judgment', 'identifi', 'diagnos') 15
# ('identifi', 'diagnos', 'solv') 15
# ('diagnos', 'solv', 'problem') 15
# ('solv', 'problem', 'rule') 15
# ('problem', 'rule', 'work') 15
# ...
